# %%
import requests

url = "http://127.0.0.1:5000/input"

payload = {}
files=[
  ('file',('testfile2.xlsx',open(r'C:/Users/deepe/Downloads/testfile2.xlsx','rb'),'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet'))
]
headers = {}

response = requests.request("GET", url, headers=headers, data=payload, files=files)

print(response.text)
# Out:
# {
#   "model_name": "Distil-Bert-Base-Uncased-Model",
#   "output": {
#     "A warm, sunny day instantly lifts my spirits.": "happiness",
#     "Anticipation fuels my motivation to work towards my goals.": "anticipation",
#     "Being in a neutral state helps me make rational decisions.": "approval",
#     "Disgust can be a protective response to harmful substances.": "neutral",
#     "Experiencing a near-miss car accident left me feeling terrified.": "fear",
#     "Happiness is contagious, spread it around.": "happiness",
#     "Happiness radiates from her eyes.": "happiness",
#     "I can feel the anger rising within me, and I need to cool down.": "anger",
#     "I can't help but smile when I hear my favorite song.": "happiness",
#     "I desire to be the best version of myself every day.": "desire",
#     "I desire to make a positive impact on the world.": "desire",
#     "I feel a sense of sadness when I think about the past.": "sadness",
# ...
